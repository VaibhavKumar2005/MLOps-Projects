# %%
# %pip install yfinance mlflow pandas

# %%
import yfinance as yf
import pandas as pd

ticker = "AAPL"

df = yf.download(
    ticker,
    start="2020-01-01",
    end="2025-12-31"
)

display(df.head())

# %%
spark_df = spark.createDataFrame(df.reset_index())

spark_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("stock_data")
